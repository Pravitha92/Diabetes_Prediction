# %%
#step1
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score

import seaborn as sns

# %%
#step2
df = pd.read_csv('diabetes.csv')

# %% [markdown]
# # step3:Exploratory Data Analysis.
#
# EDA also known as Data Exploration, is a step in the Data analysis Process, where a number of techniques are used to better understand the dataset being used.
#
# In this step, we will perform below operations:
#
# 3.1) Understanding your variables
#  a. Head of the dataset.
#  b. the shape of the dataset.
#  c.List types of all columns
#  d.Info of the dataset
#  e. Summary of the dataset
#
#
# 3.2) Data cleaning.
# a). Check the duplicates.
# b). check the null values.

# %%
#disply top 5 records.
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
#3.1b. Shape of the dataset
df.shape
# Out:
# (768, 9)

# %%
#3.1c. List the type of all coloumns.
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# #3.1.d).Info() is used to check the information about the data and the datatypes of each respective attribute.

# %%
#finding out if the dataset contains any null value
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# 3.1.e) SUMMARY of the dataset
# The described method will help to see how data has been spread for numerical values.We can clearly see the
# minimum value,mean value,differentpercentile values,and maximum values.

# %%
#statistical summary
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# # Observation:
# In the above table, the min value of columns 'Glucose','BloodPressure','SkinThickness','Insulin' 'BMI' is zero(0).It is clear that this values cant be zero.So iam going to impute mean values of these respective columns instead of zero.

# %% [markdown]
# # Data Cleaning

# %%
#3.2.1. Drop duplicates.

# %%
#check the shape before drop the duplicates.
df.shape
# Out:
# (768, 9)

# %%
df=df.drop_duplicates()

# %%
#check the shape before drop the duplicates.
df.shape
# Out:
# (768, 9)

# %%
#3.2.2 Check the null values.

# %%
df.isnull().sum() #there is no NULL values in the dataset.
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# # check the no.of Zero values in the Dataset

# %%
print('No.of zero values in Glucose',df[df['Glucose']==0].shape[0])
print('No.of zero values in BloodPressure',df[df['BloodPressure']==0].shape[0])
print('No.of zero values in SkinThickness',df[df['SkinThickness']==0].shape[0])
print('No.of zero values in Insulin',df[df['Insulin']==0].shape[0])
print('No.of zero values in BMI',df[df['BMI']==0].shape[0])
# Out:
# No.of zero values in Glucose 5
# No.of zero values in BloodPressure 35
# No.of zero values in SkinThickness 227
# No.of zero values in Insulin 374
# No.of zero values in BMI 11

# %% [markdown]
# # Replace no.of zero values with mean of that columns

# %%
df['Glucose']=df['Glucose'].replace(0,df['Glucose'].mean())
df['BloodPressure']=df['BloodPressure'].replace(0,df['BloodPressure'].mean())
df['SkinThickness']=df['SkinThickness'].replace(0,df['SkinThickness'].mean())
df['Insulin']=df['Insulin'].replace(0,df['Insulin'].mean())
df['BMI']=df['BMI'].replace(0,df['BMI'].mean())

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.681605      72.254807      26.606479  118.660163
# std       3.369578   30.436016      12.115932       9.631241   93.080358
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      20.536458   79.799479
# 50%       3.000000  117.000000      72.000000      23.000000   79.799479
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450805                  0.471876   33.240885    0.348958
# std      6.875374                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# # 4.Data visualization¶

# %% [markdown]
# 4.1) count plot

# %%
#outcome count plot
f,ax=plt.subplots(1,2,figsize=(10,5))
df['Outcome'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Outcome')
ax[0].set_ylabel('')
sns.countplot('Outcome',data=df,ax=ax[1])
ax[1].set_title('Outcome')
N,P = df['Outcome'].value_counts()
print('Negative (0): ',N)
print('Positive (1): ',P)
plt.grid()
plt.show()
# Out:
# E:\program files1\Anaconda\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Negative (0):  500
# Positive (1):  268

# %% [markdown]
# Our total 768 people,268 are diabetic(Positive(1)) and 500 are non-diabetic(negative(0))
#
# In the outcome column,1 represents diabetes positive and 0 represents diabetes negative.
#
# The countplot tells us that the dataset is imbalanced,as number of patients who dont have diabetes
# is more than those who have diabetes.
#
# We need to use some techniques for balancing the dataset like undersampling...

# %% [markdown]
# 4.2)Histogram

# %% [markdown]
# Histogram are one of the most common graphs used to display numeric data
#
# Distribution of the data-Whether the data is notmally distributed or if its skewed(to the left or right)

# %%
df.hist(bins=10,figsize=(10,10))
plt.show()

# %% [markdown]
# Scatterplot

# %% [markdown]
# A Scatterplot is atype of graph which plots the values of two variables along two axes,like age and height.Scatteerplots are useful for many reasons;like correlation matrices,it allows you to quickly understand a relationship between two matrices.

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df,figsize= (20,20));

# %% [markdown]
# 4.4) Pairplot

# %% [markdown]
# This is a great way to create scatterplots between all of your variables.

# %%
sns.pairplot(data=df,hue='Outcome')
plt.show()

# %% [markdown]
# # 4.5) Analyzing relationships between variables

# %% [markdown]
# Correlation Analysis
#
# Correlation analysis is used to quantify the degree to which two variables are related. Through the correlatio analysis,you evaluate correlation coefficient tells you how much one variable changes when the other does. Correlation analysis provides you with a linear relationship between two variables,when we correlate feature variables with the target variable, we get to know that how much dependency is there between particular feature variables and target variable.

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(10,10))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# # Observations:

# %% [markdown]
# From the correlation heatmap,we can see that there is a high correlation between Outcome and [Pregnancies,Glucose,BMI,Age,Insulin].We can select these features to accept input from the user and predict the outcome.

# %% [markdown]
# # 5). Split the data frame into X &Y

# %%
target_name='Outcome'

#Separate object for target feature
Y=df[target_name]

#Separate object for input feature
X=df.drop(target_name,axis=1)

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0            6    148.0           72.0      35.000000   79.799479  33.6
# 1            1     85.0           66.0      29.000000   79.799479  26.6
# 2            8    183.0           64.0      20.536458   79.799479  23.3
# 3            1     89.0           66.0      23.000000   94.000000  28.1
# 4            0    137.0           40.0      35.000000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
Y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %% [markdown]
# # 6).Apply Feature Scaling

# %%
#Apply Standard Scalar.
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
scalar.fit(X)
ssx=scalar.transform(X)

# %% [markdown]
# Inplace of Standard Scalar you have to try other data scaling techniques like normalizer,minmax and binarzer

# %%
print(ssx)
# Out:
# [[ 0.63994726  0.86527574 -0.0210444  ...  0.16725546  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.20598931 -0.51658286 ... -0.85153454 -0.36506078
#   -0.19067191]
#  [ 1.23388019  2.01597855 -0.68176235 ... -1.33182125  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808  -0.02240928 -0.0210444  ... -0.90975111 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.14197684 -1.01212132 ... -0.34213954 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.94297153 -0.18622389 ... -0.29847711 -0.47378505
#   -0.87137393]]

# %% [markdown]
# # 7).Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(ssx,Y, test_size = 0.2, random_state=7)

# %%
X_train.shape, Y_train.shape
# Out:
# ((614, 8), (614,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((154, 8), (154,))

# %%
# Initialzing empty lists to append all model's name and corresponding name
acc = []
model = []

# %% [markdown]
# # 8). Build the Classification Algorithms.

# %% [markdown]
# # 8.1). Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

#from sklearn.metrics import classification_report
lr=LogisticRegression(solver='liblinear',multi_class='ovr')
lr.fit(X_train,Y_train)

lr_pred=lr.predict(X_test)

#print("Train Accuracy of Logistic Regression",lr.score(X_train,Y_train)*100)
#print("Accuracy (Test) score of Logistic Regression",lr.score(X_test,Y_test)*100)
#print("Accuracy (Test) score of Logistic Regression",accuracy_score(Y_test,lr_pred)*100)


x = metrics.accuracy_score(Y_test, lr_pred)
acc.append(x)
model.append('Logistic Regression')
print("Logistic Regression's Accuracy is: ", x*100)
print('\nClassification Report of Logistic Regression:\n',classification_report(Y_test,lr_pred))
# Out:
# Logistic Regression's Accuracy is:  77.27272727272727
#
# Classification Report of Logistic Regression:
#                precision    recall  f1-score   support
#
#            0       0.78      0.89      0.83        97
#            1       0.75      0.58      0.65        57
#
#     accuracy                           0.77       154
#    macro avg       0.77      0.73      0.74       154
# weighted avg       0.77      0.77      0.77       154

# %%
# Cross validation score (Logistic Regression)
from sklearn.model_selection import cross_val_score #cross_val_score is used to measure accuracy of the model.
score = cross_val_score(lr,X,Y,cv=5)
score
# Out:
# array([0.74025974, 0.74025974, 0.74675325, 0.79738562, 0.77124183])

# %% [raw]
# # Confusion Matrix Of Logistic Regression

# %%
from sklearn.metrics import classification_report,confusion_matrix
cm=confusion_matrix(Y_test,lr_pred)
cm
# Out:
# array([[86, 11],
#        [24, 33]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(Y_test,lr_pred),annot=True,fmt="d")

# %%
#Making the confusion matrix of Logistic Regression
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import accuracy_score,roc_auc_score,roc_curve
cm=confusion_matrix(Y_test,lr_pred)

print('TN - True Negative {}'.format(cm[0,0]))
print('FP - False Positive {}'.format(cm[0,1]))
print('FN - False Negative {}'.format(cm[1,0]))
print('TP - True Positive {}'.format(cm[1,1]))
print('Accuracy Rate: {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]),np.sum(cm))*100))
print('Misclassification Rate: {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))*100))
# Out:
# TN - True Negative 86
# FP - False Positive 11
# FN - False Negative 24
# TP - True Positive 33
# Accuracy Rate: 77.27272727272727
# Misclassification Rate: 22.727272727272727

# %%
pd.crosstab(Y_test,lr_pred,rownames=['Actual values'],colnames=['Predicted values'],margins=True)
# Out:
# Predicted values    0   1  All
# Actual values
# 0                  86  11   97
# 1                  24  33   57
# All               110  44  154

# %% [raw]
# Precision(PPV-Positive Predicted Value)

# %%
TN=cm[0,0]
FP=cm[0,1]
FN=cm[1,0]
TP=cm[1,1]

# %%
#Print precision score.
precision_score=TP/float(TP+FP)*100
print('precision_score : {0:04f}'.format(precision_score))
# Out:
# precision_score : 75.000000

# %% [raw]
# Recall(True Positive Rate(TPR))

# %% [markdown]
# It is ratio of correctly predicted positive(TP)observations to the total observations which are actually true.

# %%
recall_score=TP/float(TP+FN)*100
print('recall_score',recall_score)
# Out:
# recall_score 57.89473684210527

# %% [raw]
# False Postive Rate(FPR)

# %%
FPR = FP/float(FP+TN)*100
print('False Positive Rate:{0:0.4f}'.format(FPR))
# Out:
# False Positive Rate:11.3402

# %% [raw]
# ROC curve & ROC AUC

# %%
#Area under curve
auc= roc_auc_score(Y_test,lr_pred)
print("ROC AUC score of Logistic Regression is",auc)
# Out:
# ROC AUC score of Logistic Regression is 0.7327726532826913

# %%
fpr,tpr,thresholds = roc_curve(Y_test,lr_pred)
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='darkblue',linestyle='--',label='ROC curve (area =%0.2f)'%auc)
plt.xlabel('False Positive rate')
plt.ylabel('True Positive rate')
plt.title('Reciever Operating Characteristics (ROC) curve of Logistic Regression')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)

knn_pred=knn.predict(X_test) #Prediction

x = metrics.accuracy_score(Y_test, knn_pred) # Model Evaluation
acc.append(x)
model.append('Logistic Regression')
print("K-Nearest Neighbour's Accuracy is: ", x*100)
print('\nClassification Report of K-Nearest Neighbour:\n',classification_report(Y_test,knn_pred))
# Out:
# K-Nearest Neighbour's Accuracy is:  74.67532467532467
#
# Classification Report of K-Nearest Neighbour:
#                precision    recall  f1-score   support
#
#            0       0.77      0.85      0.81        97
#            1       0.69      0.58      0.63        57
#
#     accuracy                           0.75       154
#    macro avg       0.73      0.71      0.72       154
# weighted avg       0.74      0.75      0.74       154

# %%
# Cross validation score (Logistic Regression)
#cross_val_score is used to measure accuracy of the model.
score = cross_val_score(lr,X,Y,cv=5)
score
